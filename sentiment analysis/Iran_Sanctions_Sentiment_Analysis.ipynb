# %%
#Import the libraries
from textblob import TextBlob
import nltk
import pandas as pd
from textblob import TextBlob
import pandas as pd
import string
import re
from string import digits
from sklearn.feature_extraction.stop_words import ENGLISH_STOP_WORDS
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from gensim import corpora
import gensim
import matplotlib.pyplot as plt
from stemming.porter2 import stem
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-5da757d933df> in <module>
#      14 import gensim
#      15 import matplotlib.pyplot as plt
# ---> 16 from stemming.porter2 import stem
#
# ModuleNotFoundError: No module named 'stemming'

# %%
import io 
import codecs
import csv
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 

stop_words = set(stopwords.words('english')) 
file1 = codecs.open('iran_sanctions_reddit.csv','r','utf-8') 
line = file1.read() 
words = line.split()
for r in words: 
    if not r in stop_words: 
        appendFile = open('iran_sanctions_reddit.csv','a', encoding='utf-8') 
        appendFile.write(r)
        appendFile.write("\n")
        appendFile.close()

# %%
sanctions = pd.read_csv( 'iran_sanctions_reddit.csv')
sanctions = sanctions.dropna()

# %%
sanctions = sanctions[sanctions['comments'] != '[deleted]']

# %%
def preprocessing(x):
    x = x.lower()
#     x = x.replace('—', ' ')
    x = x.replace('-', ' ')
    x = re.sub('\w+@\w+\.[a-z]{3}', ' ', x)
    x = x.translate(str.maketrans(" ", " ", string.punctuation))
    x = x.translate(str.maketrans('', '', digits))
    x = x.replace('“', '')
    x = x.replace('”', '')
    x = x.replace('…', '')
    x = x.replace('’', '')
    x = x.replace('‘', '')  
    x = ' '.join(x.split())
    x = x.split('—')
#     print(x)
    if(x[0].isupper()):
        x = x[1:]
    x = ' '.join(x)
    x = x.strip()
    x = x.replace('  ', '')
    return x
sanctions['comments'].apply(preprocessing)
# Out:
# 0       ive read the article and i still have no idea ...
# 1       poor saudi arabia you cant even commit a large...
# 2       without any proof iran was involvedgee no agen...
# 3       the same people that manufactured on command p...
# 4             oh there is coming back from this stupidity
# 5                                                     oof
# 6       these are remakes of old sanctions its a trend...
# 7       another article here says they affected food a...
# 8                            you hit the nail on the head
# 9       well we have to do something to distract the m...
# 10      httpswwwnprorgwhat we know about the attack on...
# 11      theres a mountain load of evidence iran is beh...
# 12      sanctions by their nature are done to fulfill ...
# 13      he reheats leftover sanctions hopefully he doe...
# 14                              effective for distraction
# 15      you dont seem very distracted and most people ...
# ...

# %%
def get_stemmed_text(corpus):
    from nltk.stem.porter import PorterStemmer
    stemmer = PorterStemmer()
    return [' '.join([stemmer.stem(word) for word in review.split()]) for review in corpus]

sanctions['comments'].apply(get_stemmed_text)
sanctions.head()
# Out:
#                                             comments
# 0  I've read the article. And I still have no ide...
# 1  Poor Saudi Arabia you can’t even commit a larg...
# 2  Without any proof Iran was involved..gee, no a...
# 3  The same people that manufactured, on command,...
# 4      Oh, there is coming back from this stupidity.

# %%
comments = sanctions['comments']
counter = 0
positive_sentiment_array = []
negative_sentiment_array = []
sentiment_score_array = []
label_array = []
topic_array = []
for comment in comments:
    counter += 1
    obj = TextBlob( comment )
    sentiment = obj.sentiment.polarity
    if sentiment > 0.0:
            positive_sentiment_array.append(obj)
            label_array.append("positive")
    if sentiment <0.0:
            negative_sentiment_array.append(obj)
            label_array.append("negative")
    if sentiment == 0.0:
            label_array.append('neutral')
    sentiment_score_array.append(sentiment)
    topic_array.append("Iran Sanctions")
    
#returns the sentiment of text
#by returning a value between -1.0 and 1.0

print(len(positive_sentiment_array))
print(len(negative_sentiment_array))
print(counter)
# Out:
# 1584
# 979
# 3538

# %%
sanctions.insert(1, "Score", sentiment_score_array , True) 
sanctions.insert(2, "Label", label_array , True) 
sanctions.insert(3, "Topic", topic_array , True)

# %%
sanctions.to_csv('Iran_Sanctions_SentimentAnalysis.csv',encoding='utf-8-sig')

# %%
sanctions
# Out:
#                                                comments         Score  \
# 0     I've read the article. And I still have no ide...  0.000000e+00
# 1     Poor Saudi Arabia you can’t even commit a larg... -9.285714e-02
# 2     Without any proof Iran was involved..gee, no a...  0.000000e+00
# 3     The same people that manufactured, on command,...  5.000000e-01
# 4         Oh, there is coming back from this stupidity. -3.000000e-01
# 5                                                   Oof  0.000000e+00
# 6     These are remakes of old sanctions. It's a tre...  1.000000e-01
# 7     Another article here says they affected food a... -1.666667e-01
# 8                         You hit the nail on the head.  0.000000e+00
# 9     Well we have to do SOMETHING to distract the m...  0.000000e+00
# 10    https://www.npr.org/2019/09/19/762065119/what-... -5.625000e-02
# 11    [There's a mountain load of evidence Iran is b... -7.500000e-02
# ...
