# %%
#Import the libraries
from textblob import TextBlob
import nltk
import pandas as pd
from textblob import TextBlob
import pandas as pd
import string
import re
from string import digits
from sklearn.feature_extraction.stop_words import ENGLISH_STOP_WORDS
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from gensim import corpora
import gensim
import matplotlib.pyplot as plt
from stemming.porter2 import stem
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-16-5da757d933df> in <module>
#      14 import gensim
#      15 import matplotlib.pyplot as plt
# ---> 16 from stemming.porter2 import stem
#
# ModuleNotFoundError: No module named 'stemming'

# %%
import io 
import codecs
import csv
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 

stop_words = set(stopwords.words('english')) 
file1 = codecs.open('boeing_reddit.csv','r','utf-8') 
line = file1.read() 
words = line.split()
for r in words: 
    if not r in stop_words: 
        appendFile = open('boeing_reddit.csv','a', encoding='utf-8') 
        appendFile.write(r)
        appendFile.write("\n")
        appendFile.close()

# %%
Boeing = pd.read_csv( 'boeing_reddit.csv')
Boeing = Boeing.dropna()

# %%
def preprocessing(x):
    x = x.lower()
#     x = x.replace('—', ' ')
    x = x.replace('-', ' ')
    x = re.sub('\w+@\w+\.[a-z]{3}', ' ', x)
    x = x.translate(str.maketrans(" ", " ", string.punctuation))
    x = x.translate(str.maketrans('', '', digits))
    x = x.replace('“', '')
    x = x.replace('”', '')
    x = x.replace('…', '')
    x = x.replace('’', '')
    x = x.replace('‘', '')  
    x = ' '.join(x.split())
    x = x.split('—')
#     print(x)
    if(x[0].isupper()):
        x = x[1:]
    x = ' '.join(x)
    x = x.strip()
    x = x.replace('  ', '')
    return x
Boeing['comments'].apply(preprocessing)
# Out:
# 0        so is it then possible for families who lost l...
# 1        oh theres a precedent alright boeing did a mas...
# 2        this latest lawsuit filed against boeing marks...
# 3        they prefer the term surprise landing and find...
# 4        more than just about anything in the aviation ...
# 5        remember when boeings ceo went on tv to be int...
# 6        this could look bad for boeing johnson scrambl...
# 7        good this was absolute failure after failure o...
# 8        it is pretty fucking stupid of boeing to not j...
# 9        every industry and major corporations need to ...
# 10                                                 deleted
# 11       what happened to all the massive amount of peo...
# 12       it was all about competing with airbus boeing ...
# 13       this is why i hate the american government the...
# 14       what this article does a good job articulating...
# 15       thishttpsyoutubehtukiiznsy video does a great ...
# 16       the reason for this handling quirk was by desi...
# 17       my uncle used to work in the airline repair bu...
# 18       how do i get in on this as a pilot who flew th...
# 19       how do corporations seem to get this double st...
# 20       i wish my company could kill hundreds of peopl...
# 21       good the executive who authorised the cover up...
# 22                                       as they should be
# 23       how fucking expensive would a third aoa sensor...
# 24                               boeing ceo makes m a year
# 25       perfect time for a war with iran so boeing can...
# 26       fuck them for not valuing human life so many l...
# 27       as well they should be they should be in waaay...
# 28                        oh how i wish i was holding puts
# 29       i feel a bit hurt and dismayed that a company ...
#                                ...
# 34385            us is also fighting a trade war on fronts
# 34386    did you uh reply to me instead of the other gu...
# 34387                                              deleted
# 34388                                              deleted
# 34389     just reddit making things real weird i guess ¯ツ¯
# 34390    first off no crazy pants after reading your tw...
# 34391       eu alone has higher gdp than us so theres that
# 34392                                    yah it never ends
# 34393    after you respond causing you to be reported o...
# 34394    the eu is not a country please try again just ...
# 34395    its an economic zone that bargain for trade de...
# 34396    that will change in days when of that gdp goes...
# 34397    canada and mexico doesnt form an economic unio...
# 34398    again in days your argument will be null even ...
# 34399    i do not understand yea because you are illite...
# 34400    please go on and scream like a child throwing ...
# 34401    this is the best tldr i could make originalhtt...
# 34402    im waiting for the faa to accept their share o...
# 34403    i wonder what this means for the max internati...
# 34404    apologize and then talk about how their expert...
# 34405    ok guys pack up nothing to do here ceo apologi...
# 34406    i really hope that some stupid politician hasn...
# 34407    but he did help make boeing a little extra mon...
# 34408    does anyone know why the planes werent pulled ...
# 34409    can i apologize for my speeding ticket which c...
# 34410    apologizes he should be suicided oh and take a...
# 34411    they still havent accepted blame for letting t...
# 34412                  its stock price is a good indicator
# 34413    well its highest was around now its less than ...
# 34414                                           move along
# Name: comments, Length: 34411, dtype: object

# %%
def get_stemmed_text(corpus):
    from nltk.stem.porter import PorterStemmer
    stemmer = PorterStemmer()
    return [' '.join([stemmer.stem(word) for word in review.split()]) for review in corpus]

Boeing['comments'].apply(get_stemmed_text)
Boeing.head()
# Out:
#                                             comments
# 0  So is it then possible for families who lost  ...
# 1  Oh, there's a precedent alright .. Boeing did ...
# 2  >This latest lawsuit filed against Boeing mark...
# 3  They prefer the term "surprise landing" and fi...
# 4  More than just about anything in the aviation ...

# %%
comments = Boeing['comments']
counter = 0
positive_sentiment_array = []
negative_sentiment_array = []
sentiment_score_array = []
label_array = []
topic_array = []
for comment in comments:
    counter += 1
    obj = TextBlob( comment )
    sentiment = obj.sentiment.polarity
    if sentiment > 0.0:
            positive_sentiment_array.append(obj)
            label_array.append("positive")
    if sentiment <0.0:
            negative_sentiment_array.append(obj)
            label_array.append("negative")
    if sentiment == 0.0:
            label_array.append('neutral')
    sentiment_score_array.append(sentiment)
    topic_array.append("Boeing Crisis")
    
#returns the sentiment of text
#by returning a value between -1.0 and 1.0

print(len(positive_sentiment_array))
print(len(negative_sentiment_array))
print(counter)
# Out:
# 15826
# 8886
# 34411

# %%
# Out:
#                                                 comments
# 0      So is it then possible for families who lost  ...
# 1      Oh, there's a precedent alright .. Boeing did ...
# 2      >This latest lawsuit filed against Boeing mark...
# 3      They prefer the term "surprise landing" and fi...
# 4      More than just about anything in the aviation ...
# 5      Remember when Boeing’s CEO went on TV to be in...
# 6      "This could look bad for Boeing, Johnson. Scra...
# 7      Good. This was absolute failure after failure ...
# 8      It is pretty fucking stupid of Boeing to not j...
# 9      Every industry and major corporations need to ...
# 11     What happened to all the MASSIVE amount of peo...
# 12     It was all about competing with Airbus.\r\n\r\...
# 13     This is why I hate the American government.   ...
# 14     What this article does a good job articulating...
# 15     [This](https://youtu.be/H2tuKiiznsY) video doe...
# 16     >\tThe reason for this handling quirk was by d...
# 17     My uncle used to work in the airline repair bu...
# 18     How do I get in on this as a pilot who flew th...
# 19     How do corporations seem to get this double st...
# 20     I wish my company could kill hundreds of peopl...
# 21     good, the executive who authorised the cover u...
# 22                                    As they should be.
# 23     How fucking expensive would a third AOA sensor...
# 24                      #1Boeing CEO makes $25+M a year!
# 25     Perfect time for a war with Iran so Boeing can...
# 26     fuck them for not valuing human life. so many ...
# 27     As well they should be. They should be in waaa...
# 28                 Oh how I wish I was holding 330 Puts.
# 29     I feel a bit hurt and dismayed that a company ...
# 30     I really wish that some of the individuals wou...
# ...                                                  ...
# 34383  1.  Easy there crazy pants.  I [already said i...
# 34384  The facts in both cases are too similar to ass...
# 34385        US is also fighting a trade war on 3 fronts
# 34386  Did you uh\r\n\r\nReply to me instead of the o...
# 34389  Just Reddit making things real weird I guess.\...
# 34390  > First off, no crazy pants.\r\n\r\nAfter read...
# 34391  EU alone has higher gdp than US, so there’s that.
# 34392                                 Yah it never ends.
# 34393  After you respond, causing you to be reported ...
# 34394  The Eu is not a country, please try again. Jus...
# 34395  It’s an economic zone that bargain for trade d...
# 34396  That will change in 29 days when ~16% of that ...
# 34397  Canada and Mexico doesn’t form an economic uni...
# 34398  Again in 29 days, your argument will be null, ...
# 34399  > I do not understand\r\n\r\nYea because you a...
# 34400  Please go on and scream like a child throwing ...
# 34401  This is the best tl;dr I could make, [original...
# 34402  I'm waiting for the FAA to accept their share ...
# 34403  I wonder what this means for the 737 Max inter...
# 34404  Apologize and then talk about how their expert...
# 34405  Ok guys, pack up, nothing to do here. CEO apol...
# 34406  I really hope that some stupid politician hasn...
# 34407  But he did help make Boeing a little extra mon...
# 34408  Does anyone know why the planes weren't pulled...
# 34409  Can I apologize for my speeding ticket, which ...
# 34410  Apologizes??? He should be "suicided". Oh, and...
# 34411  They still haven't accepted blame for letting ...
# 34412               Its stock price is a good indicator.
# 34413  Well it's highest was around 450 now its less ...
# 34414                                      Move along...
#
# [33370 rows x 1 columns]

# %%
Boeing.insert(1, "Score", sentiment_score_array , True) 
Boeing.insert(2, "Label", label_array , True) 
Boeing.insert(3, "Topic", topic_array , True)

# %%
Boeing = Boeing[Boeing['comments'] != '[deleted]']

# %%
Boeing
# Out:
#                                                 comments         Score  \
# 0      So is it then possible for families who lost  ...  1.777778e-01
# 1      Oh, there's a precedent alright .. Boeing did ...  0.000000e+00
# 2      >This latest lawsuit filed against Boeing mark...  2.416667e-01
# 3      They prefer the term "surprise landing" and fi...  2.000000e-01
# 4      More than just about anything in the aviation ...  2.642857e-01
# 5      Remember when Boeing’s CEO went on TV to be in...  1.013889e-01
# 6      "This could look bad for Boeing, Johnson. Scra...  1.500000e-01
# 7      Good. This was absolute failure after failure ... -1.530612e-03
# 8      It is pretty fucking stupid of Boeing to not j... -5.595238e-02
# 9      Every industry and major corporations need to ...  8.385417e-02
# 11     What happened to all the MASSIVE amount of peo... -8.108974e-02
# 12     It was all about competing with Airbus.\r\n\r\...  2.000000e-01
# 13     This is why I hate the American government.   ... -4.000000e-01
# 14     What this article does a good job articulating...  1.516667e-01
# 15     [This](https://youtu.be/H2tuKiiznsY) video doe...  2.250000e-01
# 16     >\tThe reason for this handling quirk was by d...  1.591837e-01
# 17     My uncle used to work in the airline repair bu... -9.375000e-03
# 18     How do I get in on this as a pilot who flew th...  0.000000e+00
# 19     How do corporations seem to get this double st...  0.000000e+00
# 20     I wish my company could kill hundreds of peopl...  0.000000e+00
# 21     good, the executive who authorised the cover u...  4.500000e-01
# 22                                    As they should be.  0.000000e+00
# 23     How fucking expensive would a third AOA sensor... -1.732143e-01
# 24                      #1Boeing CEO makes $25+M a year!  0.000000e+00
# 25     Perfect time for a war with Iran so Boeing can...  1.000000e+00
# 26     fuck them for not valuing human life. so many ...  3.333333e-02
# 27     As well they should be. They should be in waaa...  3.750000e-01
# 28                 Oh how I wish I was holding 330 Puts.  0.000000e+00
# 29     I feel a bit hurt and dismayed that a company ... -1.352381e-01
# 30     I really wish that some of the individuals wou...  5.000000e-02
# ...                                                  ...           ...
# 34383  1.  Easy there crazy pants.  I [already said i...  2.375000e-02
# 34384  The facts in both cases are too similar to ass...  1.875000e-01
# 34385        US is also fighting a trade war on 3 fronts  0.000000e+00
# 34386  Did you uh\r\n\r\nReply to me instead of the o... -4.166667e-02
# 34389  Just Reddit making things real weird I guess.\... -7.500000e-01
# 34390  > First off, no crazy pants.\r\n\r\nAfter read...  2.750000e-01
# 34391  EU alone has higher gdp than US, so there’s that.  2.500000e-01
# 34392                                 Yah it never ends.  0.000000e+00
# 34393  After you respond, causing you to be reported ...  5.000000e-01
# 34394  The Eu is not a country, please try again. Jus...  0.000000e+00
# 34395  It’s an economic zone that bargain for trade d... -1.547619e-02
# 34396  That will change in 29 days when ~16% of that ... -5.000000e-01
# 34397  Canada and Mexico doesn’t form an economic uni...  2.250000e-01
# 34398  Again in 29 days, your argument will be null, ... -1.666667e-01
# 34399  > I do not understand\r\n\r\nYea because you a... -1.233581e-17
# 34400  Please go on and scream like a child throwing ...  0.000000e+00
# 34401  This is the best tl;dr I could make, [original...  2.538462e-01
# 34402  I'm waiting for the FAA to accept their share ...  0.000000e+00
# 34403  I wonder what this means for the 737 Max inter...  0.000000e+00
# 34404  Apologize and then talk about how their expert...  1.400000e-01
# 34405  Ok guys, pack up, nothing to do here. CEO apol...  4.583333e-01
# 34406  I really hope that some stupid politician hasn...  3.095238e-02
# 34407  But he did help make Boeing a little extra mon... -6.250000e-02
# 34408  Does anyone know why the planes weren't pulled...  6.666667e-02
# 34409  Can I apologize for my speeding ticket, which ...  0.000000e+00
# 34410  Apologizes??? He should be "suicided". Oh, and...  0.000000e+00
# 34411  They still haven't accepted blame for letting ... -5.000000e-02
# 34412               Its stock price is a good indicator.  7.000000e-01
# 34413  Well it's highest was around 450 now its less ... -1.111111e-01
# 34414                                      Move along...  0.000000e+00
#
#           Label          Topic
# 0      positive  Boeing Crisis
# 1       neutral  Boeing Crisis
# 2      positive  Boeing Crisis
# 3      positive  Boeing Crisis
# 4      positive  Boeing Crisis
# 5      positive  Boeing Crisis
# 6      positive  Boeing Crisis
# 7      negative  Boeing Crisis
# 8      negative  Boeing Crisis
# 9      positive  Boeing Crisis
# 11     negative  Boeing Crisis
# 12     positive  Boeing Crisis
# 13     negative  Boeing Crisis
# 14     positive  Boeing Crisis
# 15     positive  Boeing Crisis
# 16     positive  Boeing Crisis
# 17     negative  Boeing Crisis
# 18      neutral  Boeing Crisis
# 19      neutral  Boeing Crisis
# 20      neutral  Boeing Crisis
# 21     positive  Boeing Crisis
# 22      neutral  Boeing Crisis
# 23     negative  Boeing Crisis
# 24      neutral  Boeing Crisis
# 25     positive  Boeing Crisis
# 26     positive  Boeing Crisis
# 27     positive  Boeing Crisis
# 28      neutral  Boeing Crisis
# 29     negative  Boeing Crisis
# 30     positive  Boeing Crisis
# ...         ...            ...
# 34383  positive  Boeing Crisis
# 34384  positive  Boeing Crisis
# 34385   neutral  Boeing Crisis
# 34386  negative  Boeing Crisis
# 34389  negative  Boeing Crisis
# 34390  positive  Boeing Crisis
# 34391  positive  Boeing Crisis
# 34392   neutral  Boeing Crisis
# 34393  positive  Boeing Crisis
# 34394   neutral  Boeing Crisis
# 34395  negative  Boeing Crisis
# 34396  negative  Boeing Crisis
# 34397  positive  Boeing Crisis
# 34398  negative  Boeing Crisis
# 34399  negative  Boeing Crisis
# 34400   neutral  Boeing Crisis
# 34401  positive  Boeing Crisis
# 34402   neutral  Boeing Crisis
# 34403   neutral  Boeing Crisis
# 34404  positive  Boeing Crisis
# 34405  positive  Boeing Crisis
# 34406  positive  Boeing Crisis
# 34407  negative  Boeing Crisis
# 34408  positive  Boeing Crisis
# 34409   neutral  Boeing Crisis
# 34410   neutral  Boeing Crisis
# 34411  negative  Boeing Crisis
# 34412  positive  Boeing Crisis
# 34413  negative  Boeing Crisis
# 34414   neutral  Boeing Crisis
#
# [33370 rows x 4 columns]

# %%
Boeing.to_csv('Boeing_SentimentAnalysis.csv',encoding='utf-8-sig')
